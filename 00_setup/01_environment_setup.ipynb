# %% [markdown]
# <a href="https://colab.research.google.com/github/MuqeetVohra/LLM-Learning/blob/main/00_setup/01_environment_setup.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Creating virtual environment

# %%
# !python -m venv .env
# Out:
# Error: Command '['/content/LLM-Learning/.env/bin/python3', '-m', 'ensurepip', '--upgrade', '--default-pip']' returned non-zero exit status 1.

# %%
ls -a
# Out:
# ./         01_transformers_basics/  04_finetuning/     .git/
# ../        02_tokenizers/           05_inference_api/  .gitignore
# 00_setup/  03_datasets/             .env/              README.md

# %%
# !source .env/bin/activate
# Out:
# /bin/bash: line 1: .env/bin/activate: No such file or directory

# %%
# !which python
# Out:
# /usr/local/bin/python

# %% [markdown]
# Installing dependencies

# %%
# !pip install transformers[sentencepiece]

# %%
# !which python
# Out:
# /usr/local/bin/python
